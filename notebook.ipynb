# %%
from functions import load_and_chunk_document

chunks = load_and_chunk_document("sample.txt")

print("Total Chunks:", len(chunks))
print("\nFirst Chunk:\n")
print(chunks[0])
# Out:
# Total Chunks: 2
#
# First Chunk:
#
# Artificial Intelligence (AI) is the simulation of human intelligence by machines.
#
# Machine Learning is a subset of AI that enables computers to learn from data without being explicitly programmed.
#
# Deep Learning is a subset of Machine Learning that uses neural networks with multiple layers.

# %%
from functions import load_and_chunk_document, create_embeddings

chunks = load_and_chunk_document("sample.txt")

embeddings = create_embeddings(chunks)

print("Number of embeddings:", len(embeddings))
print("Embedding dimension:", len(embeddings[0]))
# Out:
# ...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 885.88it/s]
# Number of embeddings: 2
# Embedding dimension: 384

# %%
import importlib
import functions

importlib.reload(functions)

from functions import create_embeddings, load_and_chunk_document

print("Imported successfully")
# Out:
# Imported successfully

# %%
chunks = load_and_chunk_document("sample.txt")

embeddings = create_embeddings(chunks)

print("Number of embeddings:", len(embeddings))
print("Embedding dimension:", len(embeddings[0]))
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1561.29it/s]
# Number of embeddings: 2
# Embedding dimension: 384

# %%
import importlib
import functions

importlib.reload(functions)

from functions import (
    load_and_chunk_document,
    create_embeddings,
    search_chunks
)

# %%
chunks = load_and_chunk_document("sample.txt")

embeddings = create_embeddings(chunks)

results = search_chunks(
    "What is Machine Learning?",
    chunks,
    embeddings,
    k=2
)

print("Top Matching Chunks:\n")

for i, chunk in enumerate(results, 1):
    print(f"Chunk {i}:\n{chunk}\n")
# Out:
# ...
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1695.55it/s]
# Top Matching Chunks:
#
# Chunk 1:
# Artificial Intelligence (AI) is the simulation of human intelligence by machines.
#
# Machine Learning is a subset of AI that enables computers to learn from data without being explicitly programmed.
#
# Deep Learning is a subset of Machine Learning that uses neural networks with multiple layers.
#
# Chunk 2:
# Natural Language Processing (NLP) helps computers understand and generate human language.
#
# Retrieval-Augmented Generation (RAG) combines information retrieval with Large Language Models to generate accurate answers based on external documents.
